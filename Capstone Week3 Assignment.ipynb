# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')

# %% [markdown]
# #### Scrap web data using BeautifulSoup

# %%
# import BeautifulSoup for web scraping
from bs4 import BeautifulSoup

# %%
website_url = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
soup = BeautifulSoup(website_url,'lxml')
#print(soup.prettify())

# %%
# Find the table that stores the data
table = soup.find('table',{'class':'wikitable sortable'})
#table

# %%
# scrap column names
th = table.find_all('th')
cols = []
for i in th:
    cols.append(i.string.rstrip("\n\r"))
cols
# Out:
# ['Postcode', 'Borough', 'Neighbourhood']

# %%
# list of rows
l = []
table_rows = table.findAll('tr')
table_rows.pop(0)
for tr in table_rows:
    td = tr.find_all('td')
    row = [tr.text.rstrip("\n\r") for tr in td]
    if td[1].string != "Not assigned": 
        l.append(row)
l[0:5]
# Out:
# [['M3A', 'North York', 'Parkwoods'],
#  ['M4A', 'North York', 'Victoria Village'],
#  ['M5A', 'Downtown Toronto', 'Harbourfront'],
#  ['M5A', 'Downtown Toronto', 'Regent Park'],
#  ['M6A', 'North York', 'Lawrence Heights']]

# %%
# creating the dataframe
df = pd.DataFrame(l, columns=cols)

# correct the column names
df.rename(columns={'Postcode':'PostalCode', 'Neighbourhood':'Neighborhood'}, inplace=True)

# If neighborhood is not assigned, use borough for neighborhood.
mask = df.Neighborhood == 'Not assigned'
df.loc[mask, 'Neighborhood'] = df.loc[mask, 'Borough']

df=df.groupby(['PostalCode','Borough'],as_index=False).agg(lambda x: "%s" % ', '.join(x))
df.head()
# Out:
#   PostalCode      Borough                            Neighborhood
# 0        M1B  Scarborough                          Rouge, Malvern
# 1        M1C  Scarborough  Highland Creek, Rouge Hill, Port Union
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                  Woburn
# 4        M1H  Scarborough                               Cedarbrae

# %%
df.shape
# Out:
# (103, 3)

# %%
# get geographical coordinates
url = 'https://cocl.us/Geospatial_data'
df2 = pd.read_csv(url)
df2.columns.values
# Out:
# array(['Postal Code', 'Latitude', 'Longitude'], dtype=object)

# %%
# renaming column name
df2.rename(columns={'Postal Code':'PostalCode'}, inplace=True)
df2.columns.values
# Out:
# array(['PostalCode', 'Latitude', 'Longitude'], dtype=object)

# %%
# merge two dataframes
df = pd.merge(df, df2, on='PostalCode')
df.head()
# Out:
#   PostalCode      Borough                            Neighborhood   Latitude  \
# 0        M1B  Scarborough                          Rouge, Malvern  43.806686
# 1        M1C  Scarborough  Highland Creek, Rouge Hill, Port Union  43.784535
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill  43.763573
# 3        M1G  Scarborough                                  Woburn  43.770992
# 4        M1H  Scarborough                               Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %%
df.shape
# Out:
# (103, 5)

# %% [markdown]
# #### Use geopy library to get the latitude and longitude values of Toronto

# %%
address = 'Toronto, CA'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinates of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinates of Toronto are 43.653963, -79.387207.

# %% [markdown]
# #### Create a map of Toronto with neighborhoods superimposed on top.

# %%
# create map of New York using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, borough, neighborhood in zip(df['Latitude'], df['Longitude'], df['Borough'], df['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# We will be working with only boroughs that contain the word Toronto

# %%
toronto_data = df[df['Borough'].str.contains('Toronto')].sort_values(by=['Neighborhood']).reset_index(drop=True)
toronto_data.reset_index()
toronto_data.head()
# Out:
#   PostalCode           Borough  \
# 0        M5H  Downtown Toronto
# 1        M5E  Downtown Toronto
# 2        M6K      West Toronto
# 3        M7Y      East Toronto
# 4        M5V  Downtown Toronto
#
#                                         Neighborhood   Latitude  Longitude
# 0                           Adelaide, King, Richmond  43.650571 -79.384568
# 1                                        Berczy Park  43.644771 -79.373306
# 2       Brockton, Exhibition Place, Parkdale Village  43.636847 -79.428191
# 3  Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 4  CN Tower, Bathurst Quay, Island airport, Harbo...  43.628947 -79.394420

# %% [markdown]
# Visualize neighborhoods with borough containing the word Toronto.

# %%
# create map of Manhattan using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=12)

# add markers to map
for lat, lng, label in zip(toronto_data['Latitude'], toronto_data['Longitude'], toronto_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'xxx' # your Foursquare ID
CLIENT_SECRET = 'xxxx' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: xxxx
# CLIENT_SECRET:xxxx

# %%
toronto_data.loc[0, 'Neighborhood']
# Out:
# 'Adelaide, King, Richmond'

# %% [markdown]
# Get the neighborhood's latitude and longitude values.

# %%
neighborhood_latitude = toronto_data.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_longitude = toronto_data.loc[0, 'Longitude'] # neighborhood longitude value

neighborhood_name = toronto_data.loc[0, 'Neighborhood'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of Adelaide, King, Richmond are 43.65057120000001, -79.3845675.

# %% [markdown]
# #### Now, let's get the top 100 venues that are in Rouge Malvern within a radius of 500 meters.

# %% [markdown]
# First, let's create the GET request URL. Name your URL **url**.

# %%
# type your answer here
radius = 500
LIMIT = 100

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=xxxx&client_secret=xxxx&v=20180605&ll=43.65057120000001,-79.3845675&radius=500&limit=100'

# %% [markdown]
# Send GET request

# %%
results = requests.get(url).json()

# %% [markdown]
# From the Foursquare lab in the previous module, we know that all the information is in the *items* key. Before we proceed, let's borrow the **get_category_type** function from the Foursquare lab.

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# Now we are ready to clean the json and structure it into a *pandas* dataframe.

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
nearby_venues.shape
# Out:
# (100, 4)

# %% [markdown]
# And how many venues were returned by Foursquare?

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 100 venues were returned by Foursquare.

# %% [markdown]
# <a id='item2'></a>

# %% [markdown]
# ## 2. Explore Neighborhoods in Toronto

# %% [markdown]
# #### Let's create a function to repeat the same process to all the neighborhoods in Toronto

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# #### Now write the code to run the above function on each neighborhood and create a new dataframe called *toronto_venues*.

# %%
# type your answer here
toronto_venues = getNearbyVenues(names=toronto_data['Neighborhood'],
                                   latitudes=df['Latitude'],
                                   longitudes=df['Longitude']
                                  )
# Out:
# Adelaide, King, Richmond
# Berczy Park
# Brockton, Exhibition Place, Parkdale Village
# Business Reply Mail Processing Centre 969 Eastern
# CN Tower, Bathurst Quay, Island airport, Harbourfront West, King and Spadina, Railway Lands, South Niagara
# Cabbagetown, St. James Town
# Central Bay Street
# Chinatown, Grange Park, Kensington Market
# Christie
# Church and Wellesley
# Commerce Court, Victoria Hotel
# Davisville
# Davisville North
# Deer Park, Forest Hill SE, Rathnelly, South Hill, Summerhill West
# Design Exchange, Toronto Dominion Centre
# Dovercourt Village, Dufferin
# First Canadian Place, Underground city
# Forest Hill North, Forest Hill West
# Harbord, University of Toronto
# Harbourfront East, Toronto Islands, Union Station
# Harbourfront, Regent Park
# High Park, The Junction South
# Lawrence Park
# Little Portugal, Trinity
# Moore Park, Summerhill East
# North Toronto West
# Parkdale, Roncesvalles
# Rosedale
# Roselawn
# Runnymede, Swansea
# Ryerson, Garden District
# St. James Town
# Stn A PO Boxes 25 The Esplanade
# Studio District
# The Annex, North Midtown, Yorkville
# The Beaches
# The Beaches West, India Bazaar
# The Danforth West, Riverdale

# %% [markdown]
# #### Let's check the size of the resulting dataframe

# %%
print(toronto_venues.shape)
toronto_venues.head(3)
# Out:
# (298, 7)
#                Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Adelaide, King, Richmond              43.806686              -79.194353
# 1               Berczy Park              43.784535              -79.160497
# 2               Berczy Park              43.784535              -79.160497
#
#                        Venue  Venue Latitude  Venue Longitude  \
# 0                    Wendy's       43.807448       -79.199056
# 1      Royal Canadian Legion       43.782533       -79.163085
# 2  Affordable Toronto Movers       43.787919       -79.162977
#
#          Venue Category
# 0  Fast Food Restaurant
# 1                   Bar
# 2         Moving Target

# %% [markdown]
# Let's check how many venues were returned for each neighborhood

# %%
toronto_venues.groupby('Neighborhood').count()
# Out:
#                                                     Neighborhood Latitude  \
# Neighborhood
# Adelaide, King, Richmond                                                1
# Berczy Park                                                             2
# Brockton, Exhibition Place, Parkdale Village                            6
# Business Reply Mail Processing Centre 969 Eastern                       4
# CN Tower, Bathurst Quay, Island airport, Harbou...                      8
# Cabbagetown, St. James Town                                             2
# Central Bay Street                                                      6
# Chinatown, Grange Park, Kensington Market                              10
# Christie                                                                3
# Church and Wellesley                                                    4
# Commerce Court, Victoria Hotel                                          7
# Davisville                                                              6
# Davisville North                                                        4
# Deer Park, Forest Hill SE, Rathnelly, South Hil...                      9
# Design Exchange, Toronto Dominion Centre                                2
# Dovercourt Village, Dufferin                                           13
# Forest Hill North, Forest Hill West                                     4
# Harbord, University of Toronto                                         63
# Harbourfront East, Toronto Islands, Union Station                       4
# Lawrence Park                                                          34
# Little Portugal, Trinity                                                3
# Moore Park, Summerhill East                                             5
# North Toronto West                                                      3
# Parkdale, Roncesvalles                                                  5
# Rosedale                                                               20
# Roselawn                                                               17
# Runnymede, Swansea                                                      5
# Ryerson, Garden District                                                4
# St. James Town                                                          4
# Stn A PO Boxes 25 The Esplanade                                         3
# Studio District                                                         5
# The Annex, North Midtown, Yorkville                                     4
# The Beaches                                                            13
# The Beaches West, India Bazaar                                         10
# The Danforth West, Riverdale                                            5
#
#                                                     Neighborhood Longitude  \
# Neighborhood
# Adelaide, King, Richmond                                                 1
# Berczy Park                                                              2
# Brockton, Exhibition Place, Parkdale Village                             6
# Business Reply Mail Processing Centre 969 Eastern                        4
# CN Tower, Bathurst Quay, Island airport, Harbou...                       8
# Cabbagetown, St. James Town                                              2
# Central Bay Street                                                       6
# Chinatown, Grange Park, Kensington Market                               10
# Christie                                                                 3
# Church and Wellesley                                                     4
# Commerce Court, Victoria Hotel                                           7
# Davisville                                                               6
# Davisville North                                                         4
# Deer Park, Forest Hill SE, Rathnelly, South Hil...                       9
# Design Exchange, Toronto Dominion Centre                                 2
# Dovercourt Village, Dufferin                                            13
# Forest Hill North, Forest Hill West                                      4
# Harbord, University of Toronto                                          63
# Harbourfront East, Toronto Islands, Union Station                        4
# Lawrence Park                                                           34
# Little Portugal, Trinity                                                 3
# Moore Park, Summerhill East                                              5
# North Toronto West                                                       3
# Parkdale, Roncesvalles                                                   5
# Rosedale                                                                20
# Roselawn                                                                17
# Runnymede, Swansea                                                       5
# Ryerson, Garden District                                                 4
# St. James Town                                                           4
# Stn A PO Boxes 25 The Esplanade                                          3
# Studio District                                                          5
# The Annex, North Midtown, Yorkville                                      4
# The Beaches                                                             13
# The Beaches West, India Bazaar                                          10
# The Danforth West, Riverdale                                             5
#
#                                                     Venue  Venue Latitude  \
# Neighborhood
# Adelaide, King, Richmond                                1               1
# Berczy Park                                             2               2
# Brockton, Exhibition Place, Parkdale Village            6               6
# Business Reply Mail Processing Centre 969 Eastern       4               4
# CN Tower, Bathurst Quay, Island airport, Harbou...      8               8
# Cabbagetown, St. James Town                             2               2
# Central Bay Street                                      6               6
# Chinatown, Grange Park, Kensington Market              10              10
# Christie                                                3               3
# Church and Wellesley                                    4               4
# Commerce Court, Victoria Hotel                          7               7
# Davisville                                              6               6
# Davisville North                                        4               4
# Deer Park, Forest Hill SE, Rathnelly, South Hil...      9               9
# Design Exchange, Toronto Dominion Centre                2               2
# Dovercourt Village, Dufferin                           13              13
# Forest Hill North, Forest Hill West                     4               4
# Harbord, University of Toronto                         63              63
# Harbourfront East, Toronto Islands, Union Station       4               4
# Lawrence Park                                          34              34
# Little Portugal, Trinity                                3               3
# Moore Park, Summerhill East                             5               5
# North Toronto West                                      3               3
# Parkdale, Roncesvalles                                  5               5
# Rosedale                                               20              20
# Roselawn                                               17              17
# Runnymede, Swansea                                      5               5
# Ryerson, Garden District                                4               4
# St. James Town                                          4               4
# Stn A PO Boxes 25 The Esplanade                         3               3
# Studio District                                         5               5
# The Annex, North Midtown, Yorkville                     4               4
# The Beaches                                            13              13
# The Beaches West, India Bazaar                         10              10
# The Danforth West, Riverdale                            5               5
#
#                                                     Venue Longitude  \
# Neighborhood
# Adelaide, King, Richmond                                          1
# Berczy Park                                                       2
# Brockton, Exhibition Place, Parkdale Village                      6
# Business Reply Mail Processing Centre 969 Eastern                 4
# CN Tower, Bathurst Quay, Island airport, Harbou...                8
# Cabbagetown, St. James Town                                       2
# Central Bay Street                                                6
# Chinatown, Grange Park, Kensington Market                        10
# Christie                                                          3
# Church and Wellesley                                              4
# Commerce Court, Victoria Hotel                                    7
# Davisville                                                        6
# Davisville North                                                  4
# Deer Park, Forest Hill SE, Rathnelly, South Hil...                9
# Design Exchange, Toronto Dominion Centre                          2
# Dovercourt Village, Dufferin                                     13
# Forest Hill North, Forest Hill West                               4
# Harbord, University of Toronto                                   63
# Harbourfront East, Toronto Islands, Union Station                 4
# Lawrence Park                                                    34
# Little Portugal, Trinity                                          3
# Moore Park, Summerhill East                                       5
# North Toronto West                                                3
# Parkdale, Roncesvalles                                            5
# Rosedale                                                         20
# Roselawn                                                         17
# Runnymede, Swansea                                                5
# Ryerson, Garden District                                          4
# St. James Town                                                    4
# Stn A PO Boxes 25 The Esplanade                                   3
# Studio District                                                   5
# The Annex, North Midtown, Yorkville                               4
# The Beaches                                                      13
# The Beaches West, India Bazaar                                   10
# The Danforth West, Riverdale                                      5
#
#                                                     Venue Category
# Neighborhood
# Adelaide, King, Richmond                                         1
# Berczy Park                                                      2
# Brockton, Exhibition Place, Parkdale Village                     6
# Business Reply Mail Processing Centre 969 Eastern                4
# CN Tower, Bathurst Quay, Island airport, Harbou...               8
# Cabbagetown, St. James Town                                      2
# Central Bay Street                                               6
# Chinatown, Grange Park, Kensington Market                       10
# Christie                                                         3
# Church and Wellesley                                             4
# Commerce Court, Victoria Hotel                                   7
# Davisville                                                       6
# Davisville North                                                 4
# Deer Park, Forest Hill SE, Rathnelly, South Hil...               9
# Design Exchange, Toronto Dominion Centre                         2
# Dovercourt Village, Dufferin                                    13
# Forest Hill North, Forest Hill West                              4
# Harbord, University of Toronto                                  63
# Harbourfront East, Toronto Islands, Union Station                4
# Lawrence Park                                                   34
# Little Portugal, Trinity                                         3
# Moore Park, Summerhill East                                      5
# North Toronto West                                               3
# Parkdale, Roncesvalles                                           5
# Rosedale                                                        20
# Roselawn                                                        17
# Runnymede, Swansea                                               5
# Ryerson, Garden District                                         4
# St. James Town                                                   4
# Stn A PO Boxes 25 The Esplanade                                  3
# Studio District                                                  5
# The Annex, North Midtown, Yorkville                              4
# The Beaches                                                     13
# The Beaches West, India Bazaar                                  10
# The Danforth West, Riverdale                                     5

# %% [markdown]
# #### Let's find out how many unique categories can be curated from all the returned venues

# %%
print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# There are 117 uniques categories.

# %% [markdown]
# <a id='item3'></a>

# %% [markdown]
# ## 3. Analyze Each Neighborhood

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

toronto_onehot.head(1)
# Out:
#    Women's Store  Airport  American Restaurant  Arts & Crafts Store  \
# 0              0        0                    0                    0
#
#    Asian Restaurant  Athletics & Sports  Auto Garage  Bakery  Bank  Bar  \
# 0                 0                   0            0       0     0    0
#
#    Baseball Field  Beer Store  Bike Shop  Boutique  Breakfast Spot  \
# 0               0           0          0         0               0
#
#    Bridal Shop  Bubble Tea Shop  Burger Joint  Burrito Place  Bus Line  \
# 0            0                0             0              0         0
#
#    Bus Station  Bus Stop  Butcher  Café  Candy Store  Caribbean Restaurant  \
# 0            0         0        0     0            0                     0
#
#    Chinese Restaurant  Clothing Store  Coffee Shop  College Stadium  \
# 0                   0               0            0                0
#
#    Construction & Landscaping  Cosmetics Shop  Curling Ice  Deli / Bodega  \
# 0                           0               0            0              0
#
#    Department Store  Dim Sum Restaurant  Diner  Discount Store  Dog Run  \
# 0                 0                   0      0               0        0
#
#    Electronics Store  Fast Food Restaurant  Food & Drink Shop  Food Court  \
# 0                  0                     1                  0           0
#
#    Food Truck  Fried Chicken Joint  Frozen Yogurt Shop  \
# 0           0                    0                   0
#
#    Furniture / Home Store  Gastropub  General Entertainment  Golf Course  \
# 0                       0          0                      0            0
#
#    Greek Restaurant  Grocery Store  Gym  Gym / Fitness Center  \
# 0                 0              0    0                     0
#
#    Hakka Restaurant  Health Food Store  Hockey Arena  Hotel  \
# 0                 0                  0             0      0
#
#    Indian Restaurant  Indonesian Restaurant  Intersection  Italian Restaurant  \
# 0                  0                      0             0                   0
#
#    Japanese Restaurant  Juice Bar  Kids Store  Korean Restaurant  \
# 0                    0          0           0                  0
#
#    Latin American Restaurant  Liquor Store  Lounge  Luggage Store  \
# 0                          0             0       0              0
#
#    Massage Studio  Medical Center  Mediterranean Restaurant  Metro Station  \
# 0               0               0                         0              0
#
#    Mexican Restaurant  Middle Eastern Restaurant  Miscellaneous Shop  Motel  \
# 0                   0                          0                   0      0
#
#    Movie Theater  Moving Target              Neighborhood  Noodle House  Park  \
# 0              0              0  Adelaide, King, Richmond             0     0
#
#    Pet Store  Pharmacy  Pizza Place  Playground  Plaza  Pool  \
# 0          0         0            0           0      0     0
#
#    Portuguese Restaurant  Pub  Ramen Restaurant  Rental Car Location  \
# 0                      0    0                 0                    0
#
#    Restaurant  Rock Climbing Spot  Salon / Barbershop  Sandwich Place  \
# 0           0                   0                   0               0
#
#    Shopping Mall  Skating Rink  Smoke Shop  Smoothie Shop  Soccer Field  Spa  \
# 0              0             0           0              0             0    0
#
#    Sporting Goods Shop  Steakhouse  Supplement Shop  Sushi Restaurant  \
# 0                    0           0                0                 0
#
#    Tea Room  Thai Restaurant  Theater  Thrift / Vintage Store  \
# 0         0                0        0                       0
#
#    Toy / Game Store  Train Station  Video Game Store  Video Store  \
# 0                 0              0                 0            0
#
#    Vietnamese Restaurant  Wings Joint
# 0                      0            0

# %% [markdown]
# And let's examine the new dataframe size.

# %%
toronto_onehot.shape
# Out:
# (298, 117)

# %% [markdown]
# #### Next, let's group rows by neighborhood and by taking the mean of the frequency of occurrence of each category

# %%
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()

# %% [markdown]
# #### Let's confirm the new size

# %%
toronto_grouped.shape
# Out:
# (35, 117)

# %% [markdown]
# #### Let's print each neighborhood along with the top 5 most common venues

# %%
num_top_venues = 5

for hood in toronto_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = toronto_grouped[toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Adelaide, King, Richmond----
#                   venue  freq
# 0  Fast Food Restaurant   1.0
# 1         Women's Store   0.0
# 2    Mexican Restaurant   0.0
# 3            Playground   0.0
# 4           Pizza Place   0.0
#
#
# ----Berczy Park----
#            venue  freq
# 0  Moving Target   0.5
# 1            Bar   0.5
# 2  Women's Store   0.0
# 3  Metro Station   0.0
# 4     Playground   0.0
#
#
# ----Brockton, Exhibition Place, Parkdale Village----
#                  venue  freq
# 0   Mexican Restaurant  0.17
# 1          Pizza Place  0.17
# 2  Rental Car Location  0.17
# 3    Electronics Store  0.17
# 4       Medical Center  0.17
#
#
# ----Business Reply Mail Processing Centre 969 Eastern----
#                 venue  freq
# 0         Coffee Shop  0.50
# 1            Pharmacy  0.25
# 2   Korean Restaurant  0.25
# 3  Mexican Restaurant  0.00
# 4               Plaza  0.00
#
#
# ----CN Tower, Bathurst Quay, Island airport, Harbourfront West, King and Spadina, Railway Lands, South Niagara----
#                   venue  freq
# 0   Fried Chicken Joint  0.12
# 1       Thai Restaurant  0.12
# 2    Athletics & Sports  0.12
# 3  Caribbean Restaurant  0.12
# 4                Bakery  0.12
#
#
# ----Cabbagetown, St. James Town----
#                         venue  freq
# 0  Construction & Landscaping   0.5
# 1                  Playground   0.5
# 2          Mexican Restaurant   0.0
# 3                       Plaza   0.0
# 4                 Pizza Place   0.0
#
#
# ----Central Bay Street----
#                 venue  freq
# 0      Discount Store  0.33
# 1    Department Store  0.17
# 2         Coffee Shop  0.17
# 3       Train Station  0.17
# 4  Chinese Restaurant  0.17
#
#
# ----Chinatown, Grange Park, Kensington Market----
#            venue  freq
# 0       Bus Line   0.2
# 1         Bakery   0.2
# 2   Intersection   0.1
# 3  Metro Station   0.1
# 4    Bus Station   0.1
#
#
# ----Christie----
#                  venue  freq
# 0         Intersection  0.33
# 1  American Restaurant  0.33
# 2                Motel  0.33
# 3        Metro Station  0.00
# 4           Playground  0.00
#
#
# ----Church and Wellesley----
#                        venue  freq
# 0            College Stadium  0.25
# 1                       Café  0.25
# 2      General Entertainment  0.25
# 3               Skating Rink  0.25
# 4  Middle Eastern Restaurant  0.00
#
#
# ----Commerce Court, Victoria Hotel----
#                        venue  freq
# 0          Indian Restaurant  0.29
# 1      Vietnamese Restaurant  0.14
# 2         Chinese Restaurant  0.14
# 3                  Pet Store  0.14
# 4  Latin American Restaurant  0.14
#
#
# ----Davisville----
#             venue  freq
# 0  Sandwich Place  0.17
# 1  Breakfast Spot  0.17
# 2      Smoke Shop  0.17
# 3     Auto Garage  0.17
# 4          Bakery  0.17
#
#
# ----Davisville North----
#             venue  freq
# 0  Sandwich Place  0.25
# 1          Lounge  0.25
# 2    Skating Rink  0.25
# 3  Breakfast Spot  0.25
# 4   Women's Store  0.00
#
#
# ----Deer Park, Forest Hill SE, Rathnelly, South Hill, Summerhill West----
#                  venue  freq
# 0          Pizza Place  0.22
# 1   Italian Restaurant  0.11
# 2  Fried Chicken Joint  0.11
# 3             Pharmacy  0.11
# 4   Chinese Restaurant  0.11
#
#
# ----Design Exchange, Toronto Dominion Centre----
#            venue  freq
# 0     Playground   0.5
# 1           Park   0.5
# 2  Women's Store   0.0
# 3  Metro Station   0.0
# 4    Pizza Place   0.0
#
#
# ----Dovercourt Village, Dufferin----
#                   venue  freq
# 0    Chinese Restaurant  0.15
# 1  Fast Food Restaurant  0.15
# 2   Japanese Restaurant  0.08
# 3        Sandwich Place  0.08
# 4        Cosmetics Shop  0.08
#
#
# ----Forest Hill North, Forest Hill West----
#                       venue  freq
# 0                      Pool  0.25
# 1               Golf Course  0.25
# 2                   Dog Run  0.25
# 3  Mediterranean Restaurant  0.25
# 4                 Juice Bar  0.00
#
#
# ----Harbord, University of Toronto----
#                   venue  freq
# 0        Clothing Store  0.13
# 1  Fast Food Restaurant  0.08
# 2           Coffee Shop  0.06
# 3      Toy / Game Store  0.05
# 4            Restaurant  0.05
#
#
# ----Harbourfront East, Toronto Islands, Union Station----
#                  venue  freq
# 0  Japanese Restaurant  0.25
# 1   Chinese Restaurant  0.25
# 2                 Bank  0.25
# 3                 Café  0.25
# 4        Women's Store  0.00
#
#
# ----Lawrence Park----
#                   venue  freq
# 0      Ramen Restaurant  0.09
# 1   Japanese Restaurant  0.06
# 2           Pizza Place  0.06
# 3  Fast Food Restaurant  0.06
# 4           Coffee Shop  0.06
#
#
# ----Little Portugal, Trinity----
#                 venue  freq
# 0                Park  0.33
# 1                Bank  0.33
# 2   Electronics Store  0.33
# 3       Women's Store  0.00
# 4  Mexican Restaurant  0.00
#
#
# ----Moore Park, Summerhill East----
#            venue  freq
# 0    Coffee Shop   0.2
# 1    Pizza Place   0.2
# 2       Pharmacy   0.2
# 3  Grocery Store   0.2
# 4        Butcher   0.2
#
#
# ----North Toronto West----
#                   venue  freq
# 0                  Park  0.33
# 1  Fast Food Restaurant  0.33
# 2     Food & Drink Shop  0.33
# 3         Women's Store  0.00
# 4    Mexican Restaurant  0.00
#
#
# ----Parkdale, Roncesvalles----
#                   venue  freq
# 0   Japanese Restaurant   0.2
# 1  Gym / Fitness Center   0.2
# 2  Caribbean Restaurant   0.2
# 3                  Café   0.2
# 4                  Pool   0.2
#
#
# ----Rosedale----
#               venue  freq
# 0        Beer Store  0.10
# 1  Asian Restaurant  0.10
# 2               Gym  0.10
# 3       Coffee Shop  0.10
# 4         Bike Shop  0.05
#
#
# ----Roselawn----
#                 venue  freq
# 0         Coffee Shop  0.12
# 1         Pizza Place  0.06
# 2  Frozen Yogurt Shop  0.06
# 3      Sandwich Place  0.06
# 4               Diner  0.06
#
#
# ----Runnymede, Swansea----
#                     venue  freq
# 0             Coffee Shop   0.2
# 1                     Bar   0.2
# 2          Massage Studio   0.2
# 3  Furniture / Home Store   0.2
# 4      Miscellaneous Shop   0.2
#
#
# ----Ryerson, Garden District----
#         venue  freq
# 0     Airport  0.25
# 1  Playground  0.25
# 2        Park  0.25
# 3    Bus Stop  0.25
# 4        Pool  0.00
#
#
# ----St. James Town----
#            venue  freq
# 0          Hotel  0.25
# 1           Bank  0.25
# 2  Moving Target  0.25
# 3  Shopping Mall  0.25
# 4  Women's Store  0.00
#
#
# ----Stn A PO Boxes 25 The Esplanade----
#                 venue  freq
# 0   Korean Restaurant  0.33
# 1      Baseball Field  0.33
# 2          Food Truck  0.33
# 3       Women's Store  0.00
# 4  Mexican Restaurant  0.00
#
#
# ----Studio District----
#                   venue  freq
# 0  Gym / Fitness Center   0.2
# 1         Grocery Store   0.2
# 2    Athletics & Sports   0.2
# 3        Discount Store   0.2
# 4          Liquor Store   0.2
#
#
# ----The Annex, North Midtown, Yorkville----
#                    venue  freq
# 0  Portuguese Restaurant  0.25
# 1            Coffee Shop  0.25
# 2           Hockey Arena  0.25
# 3           Intersection  0.25
# 4       Video Game Store  0.00
#
#
# ----The Beaches----
#                   venue  freq
# 0           Pizza Place  0.15
# 1  Fast Food Restaurant  0.15
# 2          Intersection  0.08
# 3  Gym / Fitness Center  0.08
# 4              Pharmacy  0.08
#
#
# ----The Beaches West, India Bazaar----
#                 venue  freq
# 0        Skating Rink   0.2
# 1         Curling Ice   0.1
# 2  Athletics & Sports   0.1
# 3          Beer Store   0.1
# 4            Pharmacy   0.1
#
#
# ----The Danforth West, Riverdale----
#                   venue  freq
# 0           Coffee Shop   0.4
# 1                   Pub   0.2
# 2  Gym / Fitness Center   0.2
# 3         Women's Store   0.0
# 4    Mexican Restaurant   0.0

# %% [markdown]
# #### Let's put that into a *pandas* dataframe

# %% [markdown]
# First, let's write a function to sort the venues in descending order.

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# Now let's create the new dataframe and display the top 10 venues for each neighborhood.

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted
# Out:
#                                          Neighborhood  \
# 0                            Adelaide, King, Richmond
# 1                                         Berczy Park
# 2        Brockton, Exhibition Place, Parkdale Village
# 3   Business Reply Mail Processing Centre 969 Eastern
# 4   CN Tower, Bathurst Quay, Island airport, Harbo...
# 5                         Cabbagetown, St. James Town
# 6                                  Central Bay Street
# 7           Chinatown, Grange Park, Kensington Market
# 8                                            Christie
# 9                                Church and Wellesley
# 10                     Commerce Court, Victoria Hotel
# 11                                         Davisville
# 12                                   Davisville North
# 13  Deer Park, Forest Hill SE, Rathnelly, South Hi...
# 14           Design Exchange, Toronto Dominion Centre
# 15                       Dovercourt Village, Dufferin
# 16                Forest Hill North, Forest Hill West
# 17                     Harbord, University of Toronto
# 18  Harbourfront East, Toronto Islands, Union Station
# 19                                      Lawrence Park
# 20                           Little Portugal, Trinity
# 21                        Moore Park, Summerhill East
# 22                                 North Toronto West
# 23                             Parkdale, Roncesvalles
# 24                                           Rosedale
# 25                                           Roselawn
# 26                                 Runnymede, Swansea
# 27                           Ryerson, Garden District
# 28                                     St. James Town
# 29                    Stn A PO Boxes 25 The Esplanade
# 30                                    Studio District
# 31                The Annex, North Midtown, Yorkville
# 32                                        The Beaches
# 33                     The Beaches West, India Bazaar
# 34                       The Danforth West, Riverdale
#
#        1st Most Common Venue       2nd Most Common Venue  \
# 0       Fast Food Restaurant                 Wings Joint
# 1              Moving Target                         Bar
# 2             Breakfast Spot         Rental Car Location
# 3                Coffee Shop                    Pharmacy
# 4                     Lounge          Athletics & Sports
# 5                 Playground  Construction & Landscaping
# 6             Discount Store          Chinese Restaurant
# 7                     Bakery                    Bus Line
# 8        American Restaurant                Intersection
# 9            College Stadium                        Café
# 10         Indian Restaurant   Latin American Restaurant
# 11                Smoke Shop               Shopping Mall
# 12            Breakfast Spot              Sandwich Place
# 13               Pizza Place                    Pharmacy
# 14                      Park                  Playground
# 15        Chinese Restaurant        Fast Food Restaurant
# 16  Mediterranean Restaurant                        Pool
# 17            Clothing Store        Fast Food Restaurant
# 18        Chinese Restaurant         Japanese Restaurant
# 19          Ramen Restaurant                 Coffee Shop
# 20                      Park                        Bank
# 21               Coffee Shop               Grocery Store
# 22         Food & Drink Shop                        Park
# 23      Gym / Fitness Center                        Pool
# 24                       Gym                 Coffee Shop
# 25               Coffee Shop            Sushi Restaurant
# 26               Coffee Shop                         Bar
# 27                Playground                     Airport
# 28                     Hotel               Moving Target
# 29         Korean Restaurant              Baseball Field
# 30      Gym / Fitness Center               Grocery Store
# 31               Coffee Shop                Hockey Arena
# 32               Pizza Place        Fast Food Restaurant
# 33              Skating Rink              Cosmetics Shop
# 34               Coffee Shop        Gym / Fitness Center
#
#     3rd Most Common Venue       4th Most Common Venue  \
# 0              Food Court  Construction & Landscaping
# 1             Wings Joint                  Food Court
# 2      Mexican Restaurant           Electronics Store
# 3       Korean Restaurant                  Food Court
# 4     Fried Chicken Joint                        Bank
# 5       Food & Drink Shop             College Stadium
# 6           Train Station            Department Store
# 7                    Park                Soccer Field
# 8                   Motel                 Wings Joint
# 9   General Entertainment                Skating Rink
# 10  Vietnamese Restaurant                   Pet Store
# 11         Breakfast Spot              Sandwich Place
# 12                 Lounge                Skating Rink
# 13   Fast Food Restaurant          Chinese Restaurant
# 14            Wings Joint           Food & Drink Shop
# 15         Breakfast Spot         Japanese Restaurant
# 16            Golf Course                     Dog Run
# 17            Coffee Shop            Toy / Game Store
# 18                   Café                        Bank
# 19             Restaurant        Fast Food Restaurant
# 20      Electronics Store                 Wings Joint
# 21               Pharmacy                     Butcher
# 22   Fast Food Restaurant                 Wings Joint
# 23    Japanese Restaurant        Caribbean Restaurant
# 24       Asian Restaurant                  Beer Store
# 25         Sandwich Place               Shopping Mall
# 26     Miscellaneous Shop      Furniture / Home Store
# 27                   Park                    Bus Stop
# 28                   Bank               Shopping Mall
# 29             Food Truck                 Wings Joint
# 30     Athletics & Sports                Liquor Store
# 31           Intersection       Portuguese Restaurant
# 32   Gym / Fitness Center                        Bank
# 33                    Spa                  Beer Store
# 34                    Pub                 Wings Joint
#
#          5th Most Common Venue       6th Most Common Venue  \
# 0               Cosmetics Shop                 Curling Ice
# 1               Cosmetics Shop                 Curling Ice
# 2               Medical Center                 Pizza Place
# 3               Cosmetics Shop                 Curling Ice
# 4              Thai Restaurant        Caribbean Restaurant
# 5               Cosmetics Shop                 Curling Ice
# 6                  Coffee Shop                 Wings Joint
# 7                Metro Station                Intersection
# 8                   Food Court              Cosmetics Shop
# 9         Fast Food Restaurant  Construction & Landscaping
# 10          Chinese Restaurant      Furniture / Home Store
# 11                 Auto Garage                      Bakery
# 12           Food & Drink Shop  Construction & Landscaping
# 13                Noodle House          Italian Restaurant
# 14  Construction & Landscaping              Cosmetics Shop
# 15                 Pizza Place              Cosmetics Shop
# 16                 Wings Joint  Construction & Landscaping
# 17                  Restaurant                  Kids Store
# 18                 Wings Joint                  Food Court
# 19                 Pizza Place         Japanese Restaurant
# 20                  Food Court              Cosmetics Shop
# 21                 Pizza Place                         Gym
# 22  Construction & Landscaping              Cosmetics Shop
# 23                        Café                 Wings Joint
# 24          Chinese Restaurant                  Restaurant
# 25                 Bridal Shop        Fast Food Restaurant
# 26              Massage Studio               Grocery Store
# 27           Food & Drink Shop  Construction & Landscaping
# 28           Food & Drink Shop              Cosmetics Shop
# 29                  Food Court              Cosmetics Shop
# 30              Discount Store                 Wings Joint
# 31           Food & Drink Shop  Construction & Landscaping
# 32                        Café          Rock Climbing Spot
# 33                 Curling Ice          Athletics & Sports
# 34        Fast Food Restaurant  Construction & Landscaping
#
#    7th Most Common Venue       8th Most Common Venue  \
# 0          Deli / Bodega            Department Store
# 1          Deli / Bodega            Department Store
# 2   Fast Food Restaurant  Construction & Landscaping
# 3          Deli / Bodega            Department Store
# 4                 Bakery            Hakka Restaurant
# 5          Deli / Bodega            Department Store
# 6      Food & Drink Shop  Construction & Landscaping
# 7            Bus Station        Fast Food Restaurant
# 8            Curling Ice               Deli / Bodega
# 9         Cosmetics Shop                 Curling Ice
# 10           Wings Joint           Electronics Store
# 11        Discount Store        Fast Food Restaurant
# 12        Cosmetics Shop                 Curling Ice
# 13       Thai Restaurant         Fried Chicken Joint
# 14           Curling Ice               Deli / Bodega
# 15        Sandwich Place                 Coffee Shop
# 16        Cosmetics Shop                 Curling Ice
# 17            Food Court                    Tea Room
# 18           Curling Ice               Deli / Bodega
# 19                  Café              Sandwich Place
# 20           Curling Ice               Deli / Bodega
# 21               Dog Run            Hakka Restaurant
# 22           Curling Ice               Deli / Bodega
# 23  Fast Food Restaurant              Cosmetics Shop
# 24        Sandwich Place          Dim Sum Restaurant
# 25         Deli / Bodega         Fried Chicken Joint
# 26  Fast Food Restaurant              Cosmetics Shop
# 27        Cosmetics Shop                 Curling Ice
# 28           Curling Ice               Deli / Bodega
# 29           Curling Ice               Deli / Bodega
# 30     Food & Drink Shop              Cosmetics Shop
# 31        Cosmetics Shop                 Curling Ice
# 32             Pet Store                   Gastropub
# 33              Pharmacy                        Park
# 34        Cosmetics Shop                 Curling Ice
#
#          9th Most Common Venue      10th Most Common Venue
# 0           Dim Sum Restaurant                       Diner
# 1           Dim Sum Restaurant                       Diner
# 2               Cosmetics Shop                 Curling Ice
# 3           Dim Sum Restaurant                       Diner
# 4             Department Store               Deli / Bodega
# 5           Dim Sum Restaurant                       Diner
# 6               Cosmetics Shop                 Curling Ice
# 7               Discount Store                     Dog Run
# 8             Department Store          Dim Sum Restaurant
# 9                Deli / Bodega            Department Store
# 10                     Dog Run              Discount Store
# 11           Electronics Store                     Dog Run
# 12               Deli / Bodega            Department Store
# 13            Department Store                       Diner
# 14            Department Store          Dim Sum Restaurant
# 15                    Pharmacy               Grocery Store
# 16               Deli / Bodega            Department Store
# 17                      Bakery            Asian Restaurant
# 18            Department Store          Dim Sum Restaurant
# 19               Movie Theater                       Plaza
# 20            Department Store          Dim Sum Restaurant
# 21  Construction & Landscaping              Cosmetics Shop
# 22            Department Store          Dim Sum Restaurant
# 23                 Curling Ice               Deli / Bodega
# 24                   Bike Shop         Sporting Goods Shop
# 25                  Restaurant                        Bank
# 26                 Curling Ice               Deli / Bodega
# 27               Deli / Bodega            Department Store
# 28            Department Store          Dim Sum Restaurant
# 29            Department Store          Dim Sum Restaurant
# 30                 Curling Ice               Deli / Bodega
# 31               Deli / Bodega            Department Store
# 32                    Pharmacy          Athletics & Sports
# 33                 Video Store  Construction & Landscaping
# 34               Deli / Bodega            Department Store

# %%
toronto_data
# Out:
#    PostalCode           Borough  \
# 0         M5H  Downtown Toronto
# 1         M5E  Downtown Toronto
# 2         M6K      West Toronto
# 3         M7Y      East Toronto
# 4         M5V  Downtown Toronto
# 5         M4X  Downtown Toronto
# 6         M5G  Downtown Toronto
# 7         M5T  Downtown Toronto
# 8         M6G  Downtown Toronto
# 9         M4Y  Downtown Toronto
# 10        M5L  Downtown Toronto
# 11        M4S   Central Toronto
# 12        M4P   Central Toronto
# 13        M4V   Central Toronto
# 14        M5K  Downtown Toronto
# 15        M6H      West Toronto
# 16        M5X  Downtown Toronto
# 17        M5P   Central Toronto
# 18        M5S  Downtown Toronto
# 19        M5J  Downtown Toronto
# 20        M5A  Downtown Toronto
# 21        M6P      West Toronto
# 22        M4N   Central Toronto
# 23        M6J      West Toronto
# 24        M4T   Central Toronto
# 25        M4R   Central Toronto
# 26        M6R      West Toronto
# 27        M4W  Downtown Toronto
# 28        M5N   Central Toronto
# 29        M6S      West Toronto
# 30        M5B  Downtown Toronto
# 31        M5C  Downtown Toronto
# 32        M5W  Downtown Toronto
# 33        M4M      East Toronto
# 34        M5R   Central Toronto
# 35        M4E      East Toronto
# 36        M4L      East Toronto
# 37        M4K      East Toronto
#
#                                          Neighborhood   Latitude  Longitude
# 0                            Adelaide, King, Richmond  43.650571 -79.384568
# 1                                         Berczy Park  43.644771 -79.373306
# 2        Brockton, Exhibition Place, Parkdale Village  43.636847 -79.428191
# 3   Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 4   CN Tower, Bathurst Quay, Island airport, Harbo...  43.628947 -79.394420
# 5                         Cabbagetown, St. James Town  43.667967 -79.367675
# 6                                  Central Bay Street  43.657952 -79.387383
# 7           Chinatown, Grange Park, Kensington Market  43.653206 -79.400049
# 8                                            Christie  43.669542 -79.422564
# 9                                Church and Wellesley  43.665860 -79.383160
# 10                     Commerce Court, Victoria Hotel  43.648198 -79.379817
# 11                                         Davisville  43.704324 -79.388790
# 12                                   Davisville North  43.712751 -79.390197
# 13  Deer Park, Forest Hill SE, Rathnelly, South Hi...  43.686412 -79.400049
# 14           Design Exchange, Toronto Dominion Centre  43.647177 -79.381576
# 15                       Dovercourt Village, Dufferin  43.669005 -79.442259
# 16             First Canadian Place, Underground city  43.648429 -79.382280
# 17                Forest Hill North, Forest Hill West  43.696948 -79.411307
# 18                     Harbord, University of Toronto  43.662696 -79.400049
# 19  Harbourfront East, Toronto Islands, Union Station  43.640816 -79.381752
# 20                          Harbourfront, Regent Park  43.654260 -79.360636
# 21                      High Park, The Junction South  43.661608 -79.464763
# 22                                      Lawrence Park  43.728020 -79.388790
# 23                           Little Portugal, Trinity  43.647927 -79.419750
# 24                        Moore Park, Summerhill East  43.689574 -79.383160
# 25                                 North Toronto West  43.715383 -79.405678
# 26                             Parkdale, Roncesvalles  43.648960 -79.456325
# 27                                           Rosedale  43.679563 -79.377529
# 28                                           Roselawn  43.711695 -79.416936
# 29                                 Runnymede, Swansea  43.651571 -79.484450
# 30                           Ryerson, Garden District  43.657162 -79.378937
# 31                                     St. James Town  43.651494 -79.375418
# 32                    Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 33                                    Studio District  43.659526 -79.340923
# 34                The Annex, North Midtown, Yorkville  43.672710 -79.405678
# 35                                        The Beaches  43.676357 -79.293031
# 36                     The Beaches West, India Bazaar  43.668999 -79.315572
# 37                       The Danforth West, Riverdale  43.679557 -79.352188

# %% [markdown]
# For some reason I got different results for neighborhoods_venues_sorted and toronto_data shapes. I have removed the neighborhoods that are not in neighborhoods_venues_sorted to prevent further problems when assigning labels.

# %%
neighborhoods_venues_sorted.shape
toronto_data = toronto_data[toronto_data.Neighborhood != 'Forest Hill North, Forest Hill West']
toronto_data = toronto_data[toronto_data.Neighborhood != 'Harbourfront, Regent Park']
toronto_data = toronto_data[toronto_data.Neighborhood != 'High Park, The Junction South']

# %% [markdown]
# <a id='item4'></a>

# %%
neighborhoods_venues_sorted.sort_values(by=['Neighborhood'])
toronto_data.reset_index()
toronto_data.sort_values(by=['Neighborhood'])
# Out:
#    PostalCode           Borough  \
# 0         M5H  Downtown Toronto
# 1         M5E  Downtown Toronto
# 2         M6K      West Toronto
# 3         M7Y      East Toronto
# 4         M5V  Downtown Toronto
# 5         M4X  Downtown Toronto
# 6         M5G  Downtown Toronto
# 7         M5T  Downtown Toronto
# 8         M6G  Downtown Toronto
# 9         M4Y  Downtown Toronto
# 10        M5L  Downtown Toronto
# 11        M4S   Central Toronto
# 12        M4P   Central Toronto
# 13        M4V   Central Toronto
# 14        M5K  Downtown Toronto
# 15        M6H      West Toronto
# 16        M5X  Downtown Toronto
# 18        M5S  Downtown Toronto
# 19        M5J  Downtown Toronto
# 22        M4N   Central Toronto
# 23        M6J      West Toronto
# 24        M4T   Central Toronto
# 25        M4R   Central Toronto
# 26        M6R      West Toronto
# 27        M4W  Downtown Toronto
# 28        M5N   Central Toronto
# 29        M6S      West Toronto
# 30        M5B  Downtown Toronto
# 31        M5C  Downtown Toronto
# 32        M5W  Downtown Toronto
# 33        M4M      East Toronto
# 34        M5R   Central Toronto
# 35        M4E      East Toronto
# 36        M4L      East Toronto
# 37        M4K      East Toronto
#
#                                          Neighborhood   Latitude  Longitude
# 0                            Adelaide, King, Richmond  43.650571 -79.384568
# 1                                         Berczy Park  43.644771 -79.373306
# 2        Brockton, Exhibition Place, Parkdale Village  43.636847 -79.428191
# 3   Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 4   CN Tower, Bathurst Quay, Island airport, Harbo...  43.628947 -79.394420
# 5                         Cabbagetown, St. James Town  43.667967 -79.367675
# 6                                  Central Bay Street  43.657952 -79.387383
# 7           Chinatown, Grange Park, Kensington Market  43.653206 -79.400049
# 8                                            Christie  43.669542 -79.422564
# 9                                Church and Wellesley  43.665860 -79.383160
# 10                     Commerce Court, Victoria Hotel  43.648198 -79.379817
# 11                                         Davisville  43.704324 -79.388790
# 12                                   Davisville North  43.712751 -79.390197
# 13  Deer Park, Forest Hill SE, Rathnelly, South Hi...  43.686412 -79.400049
# 14           Design Exchange, Toronto Dominion Centre  43.647177 -79.381576
# 15                       Dovercourt Village, Dufferin  43.669005 -79.442259
# 16             First Canadian Place, Underground city  43.648429 -79.382280
# 18                     Harbord, University of Toronto  43.662696 -79.400049
# 19  Harbourfront East, Toronto Islands, Union Station  43.640816 -79.381752
# 22                                      Lawrence Park  43.728020 -79.388790
# 23                           Little Portugal, Trinity  43.647927 -79.419750
# 24                        Moore Park, Summerhill East  43.689574 -79.383160
# 25                                 North Toronto West  43.715383 -79.405678
# 26                             Parkdale, Roncesvalles  43.648960 -79.456325
# 27                                           Rosedale  43.679563 -79.377529
# 28                                           Roselawn  43.711695 -79.416936
# 29                                 Runnymede, Swansea  43.651571 -79.484450
# 30                           Ryerson, Garden District  43.657162 -79.378937
# 31                                     St. James Town  43.651494 -79.375418
# 32                    Stn A PO Boxes 25 The Esplanade  43.646435 -79.374846
# 33                                    Studio District  43.659526 -79.340923
# 34                The Annex, North Midtown, Yorkville  43.672710 -79.405678
# 35                                        The Beaches  43.676357 -79.293031
# 36                     The Beaches West, India Bazaar  43.668999 -79.315572
# 37                       The Danforth West, Riverdale  43.679557 -79.352188

# %% [markdown]
# ## 4. Cluster Neighborhoods

# %% [markdown]
# Run *k*-means to cluster the neighborhood into 5 clusters.

# %%
# set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10] 
kmeans.labels_.size
# Out:
# 35

# %% [markdown]
# Let's create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood.

# %%
toronto_merged = toronto_data

# add clustering labels
toronto_merged['Cluster Labels'] = kmeans.labels_

# merge toronto_grouped with toronto data (df) to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

toronto_merged.head() # check the last columns!
# Out:
#   PostalCode           Borough  \
# 0        M5H  Downtown Toronto
# 1        M5E  Downtown Toronto
# 2        M6K      West Toronto
# 3        M7Y      East Toronto
# 4        M5V  Downtown Toronto
#
#                                         Neighborhood   Latitude  Longitude  \
# 0                           Adelaide, King, Richmond  43.650571 -79.384568
# 1                                        Berczy Park  43.644771 -79.373306
# 2       Brockton, Exhibition Place, Parkdale Village  43.636847 -79.428191
# 3  Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 4  CN Tower, Bathurst Quay, Island airport, Harbo...  43.628947 -79.394420
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0               1  Fast Food Restaurant           Wings Joint
# 1               3         Moving Target                   Bar
# 2               3        Breakfast Spot   Rental Car Location
# 3               0           Coffee Shop              Pharmacy
# 4               3                Lounge    Athletics & Sports
#
#   3rd Most Common Venue       4th Most Common Venue 5th Most Common Venue  \
# 0            Food Court  Construction & Landscaping        Cosmetics Shop
# 1           Wings Joint                  Food Court        Cosmetics Shop
# 2    Mexican Restaurant           Electronics Store        Medical Center
# 3     Korean Restaurant                  Food Court        Cosmetics Shop
# 4   Fried Chicken Joint                        Bank       Thai Restaurant
#
#   6th Most Common Venue 7th Most Common Venue       8th Most Common Venue  \
# 0           Curling Ice         Deli / Bodega            Department Store
# 1           Curling Ice         Deli / Bodega            Department Store
# 2           Pizza Place  Fast Food Restaurant  Construction & Landscaping
# 3           Curling Ice         Deli / Bodega            Department Store
# 4  Caribbean Restaurant                Bakery            Hakka Restaurant
#
#   9th Most Common Venue 10th Most Common Venue
# 0    Dim Sum Restaurant                  Diner
# 1    Dim Sum Restaurant                  Diner
# 2        Cosmetics Shop            Curling Ice
# 3    Dim Sum Restaurant                  Diner
# 4      Department Store          Deli / Bodega

# %% [markdown]
# Finally, let's visualize the resulting clusters

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=12)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <a id='item5'></a>

# %% [markdown]
# ## 5. Examine Clusters

# %% [markdown]
# Now, you can examine each cluster and determine the discriminating venue categories that distinguish each cluster. Based on the defining categories, you can then assign a name to each cluster. I will leave this exercise to you.

# %% [markdown]
# #### Cluster 1: Coffee Shops

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 3       East Toronto               0           Coffee Shop
# 6   Downtown Toronto               0        Discount Store
# 8   Downtown Toronto               0   American Restaurant
# 24   Central Toronto               0           Coffee Shop
# 29      West Toronto               0           Coffee Shop
# 34   Central Toronto               0           Coffee Shop
# 37      East Toronto               0           Coffee Shop
#
#    2nd Most Common Venue 3rd Most Common Venue   4th Most Common Venue  \
# 3               Pharmacy     Korean Restaurant              Food Court
# 6     Chinese Restaurant         Train Station        Department Store
# 8           Intersection                 Motel             Wings Joint
# 24         Grocery Store              Pharmacy                 Butcher
# 29                   Bar    Miscellaneous Shop  Furniture / Home Store
# 34          Hockey Arena          Intersection   Portuguese Restaurant
# 37  Gym / Fitness Center                   Pub             Wings Joint
#
#    5th Most Common Venue       6th Most Common Venue 7th Most Common Venue  \
# 3         Cosmetics Shop                 Curling Ice         Deli / Bodega
# 6            Coffee Shop                 Wings Joint     Food & Drink Shop
# 8             Food Court              Cosmetics Shop           Curling Ice
# 24           Pizza Place                         Gym               Dog Run
# 29        Massage Studio               Grocery Store  Fast Food Restaurant
# 34     Food & Drink Shop  Construction & Landscaping        Cosmetics Shop
# 37  Fast Food Restaurant  Construction & Landscaping        Cosmetics Shop
#
#          8th Most Common Venue       9th Most Common Venue  \
# 3             Department Store          Dim Sum Restaurant
# 6   Construction & Landscaping              Cosmetics Shop
# 8                Deli / Bodega            Department Store
# 24            Hakka Restaurant  Construction & Landscaping
# 29              Cosmetics Shop                 Curling Ice
# 34                 Curling Ice               Deli / Bodega
# 37                 Curling Ice               Deli / Bodega
#
#    10th Most Common Venue
# 3                   Diner
# 6             Curling Ice
# 8      Dim Sum Restaurant
# 24         Cosmetics Shop
# 29          Deli / Bodega
# 34       Department Store
# 37       Department Store

# %% [markdown]
# #### Cluster 2: Restaurants

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 0   Downtown Toronto               1  Fast Food Restaurant
# 25   Central Toronto               1     Food & Drink Shop
#
#    2nd Most Common Venue 3rd Most Common Venue       4th Most Common Venue  \
# 0            Wings Joint            Food Court  Construction & Landscaping
# 25                  Park  Fast Food Restaurant                 Wings Joint
#
#          5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0               Cosmetics Shop           Curling Ice         Deli / Bodega
# 25  Construction & Landscaping        Cosmetics Shop           Curling Ice
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0       Department Store    Dim Sum Restaurant                  Diner
# 25         Deli / Bodega      Department Store     Dim Sum Restaurant

# %% [markdown]
# #### Cluster 3: Playground

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#             Borough  Cluster Labels 1st Most Common Venue  \
# 5  Downtown Toronto               2            Playground
#
#         2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 5  Construction & Landscaping     Food & Drink Shop       College Stadium
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 5        Cosmetics Shop           Curling Ice         Deli / Bodega
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 5      Department Store    Dim Sum Restaurant                  Diner

# %% [markdown]
# #### Cluster 4: Restaurant and Shops are common. Probably downtown area.

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 1   Downtown Toronto               3         Moving Target
# 2       West Toronto               3        Breakfast Spot
# 4   Downtown Toronto               3                Lounge
# 7   Downtown Toronto               3                Bakery
# 9   Downtown Toronto               3       College Stadium
# 10  Downtown Toronto               3     Indian Restaurant
# 11   Central Toronto               3            Smoke Shop
# 12   Central Toronto               3        Breakfast Spot
# 13   Central Toronto               3           Pizza Place
# 15      West Toronto               3    Chinese Restaurant
# 16  Downtown Toronto               3                   NaN
# 18  Downtown Toronto               3        Clothing Store
# 19  Downtown Toronto               3    Chinese Restaurant
# 22   Central Toronto               3      Ramen Restaurant
# 23      West Toronto               3                  Park
# 26      West Toronto               3  Gym / Fitness Center
# 27  Downtown Toronto               3                   Gym
# 28   Central Toronto               3           Coffee Shop
# 31  Downtown Toronto               3                 Hotel
# 32  Downtown Toronto               3     Korean Restaurant
# 33      East Toronto               3  Gym / Fitness Center
# 35      East Toronto               3           Pizza Place
# 36      East Toronto               3          Skating Rink
#
#         2nd Most Common Venue  3rd Most Common Venue 4th Most Common Venue  \
# 1                         Bar            Wings Joint            Food Court
# 2         Rental Car Location     Mexican Restaurant     Electronics Store
# 4          Athletics & Sports    Fried Chicken Joint                  Bank
# 7                    Bus Line                   Park          Soccer Field
# 9                        Café  General Entertainment          Skating Rink
# 10  Latin American Restaurant  Vietnamese Restaurant             Pet Store
# 11              Shopping Mall         Breakfast Spot        Sandwich Place
# 12             Sandwich Place                 Lounge          Skating Rink
# 13                   Pharmacy   Fast Food Restaurant    Chinese Restaurant
# 15       Fast Food Restaurant         Breakfast Spot   Japanese Restaurant
# 16                        NaN                    NaN                   NaN
# 18       Fast Food Restaurant            Coffee Shop      Toy / Game Store
# 19        Japanese Restaurant                   Café                  Bank
# 22                Coffee Shop             Restaurant  Fast Food Restaurant
# 23                       Bank      Electronics Store           Wings Joint
# 26                       Pool    Japanese Restaurant  Caribbean Restaurant
# 27                Coffee Shop       Asian Restaurant            Beer Store
# 28           Sushi Restaurant         Sandwich Place         Shopping Mall
# 31              Moving Target                   Bank         Shopping Mall
# 32             Baseball Field             Food Truck           Wings Joint
# 33              Grocery Store     Athletics & Sports          Liquor Store
# 35       Fast Food Restaurant   Gym / Fitness Center                  Bank
# 36             Cosmetics Shop                    Spa            Beer Store
#
#    5th Most Common Venue       6th Most Common Venue 7th Most Common Venue  \
# 1         Cosmetics Shop                 Curling Ice         Deli / Bodega
# 2         Medical Center                 Pizza Place  Fast Food Restaurant
# 4        Thai Restaurant        Caribbean Restaurant                Bakery
# 7          Metro Station                Intersection           Bus Station
# 9   Fast Food Restaurant  Construction & Landscaping        Cosmetics Shop
# 10    Chinese Restaurant      Furniture / Home Store           Wings Joint
# 11           Auto Garage                      Bakery        Discount Store
# 12     Food & Drink Shop  Construction & Landscaping        Cosmetics Shop
# 13          Noodle House          Italian Restaurant       Thai Restaurant
# 15           Pizza Place              Cosmetics Shop        Sandwich Place
# 16                   NaN                         NaN                   NaN
# 18            Restaurant                  Kids Store            Food Court
# 19           Wings Joint                  Food Court           Curling Ice
# 22           Pizza Place         Japanese Restaurant                  Café
# 23            Food Court              Cosmetics Shop           Curling Ice
# 26                  Café                 Wings Joint  Fast Food Restaurant
# 27    Chinese Restaurant                  Restaurant        Sandwich Place
# 28           Bridal Shop        Fast Food Restaurant         Deli / Bodega
# 31     Food & Drink Shop              Cosmetics Shop           Curling Ice
# 32            Food Court              Cosmetics Shop           Curling Ice
# 33        Discount Store                 Wings Joint     Food & Drink Shop
# 35                  Café          Rock Climbing Spot             Pet Store
# 36           Curling Ice          Athletics & Sports              Pharmacy
#
#          8th Most Common Venue 9th Most Common Venue  \
# 1             Department Store    Dim Sum Restaurant
# 2   Construction & Landscaping        Cosmetics Shop
# 4             Hakka Restaurant      Department Store
# 7         Fast Food Restaurant        Discount Store
# 9                  Curling Ice         Deli / Bodega
# 10           Electronics Store               Dog Run
# 11        Fast Food Restaurant     Electronics Store
# 12                 Curling Ice         Deli / Bodega
# 13         Fried Chicken Joint      Department Store
# 15                 Coffee Shop              Pharmacy
# 16                         NaN                   NaN
# 18                    Tea Room                Bakery
# 19               Deli / Bodega      Department Store
# 22              Sandwich Place         Movie Theater
# 23               Deli / Bodega      Department Store
# 26              Cosmetics Shop           Curling Ice
# 27          Dim Sum Restaurant             Bike Shop
# 28         Fried Chicken Joint            Restaurant
# 31               Deli / Bodega      Department Store
# 32               Deli / Bodega      Department Store
# 33              Cosmetics Shop           Curling Ice
# 35                   Gastropub              Pharmacy
# 36                        Park           Video Store
#
#         10th Most Common Venue
# 1                        Diner
# 2                  Curling Ice
# 4                Deli / Bodega
# 7                      Dog Run
# 9             Department Store
# 10              Discount Store
# 11                     Dog Run
# 12            Department Store
# 13                       Diner
# 15               Grocery Store
# 16                         NaN
# 18            Asian Restaurant
# 19          Dim Sum Restaurant
# 22                       Plaza
# 23          Dim Sum Restaurant
# 26               Deli / Bodega
# 27         Sporting Goods Shop
# 28                        Bank
# 31          Dim Sum Restaurant
# 32          Dim Sum Restaurant
# 33               Deli / Bodega
# 35          Athletics & Sports
# 36  Construction & Landscaping

# %% [markdown]
# #### Cluster 5: Park

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 4, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 14  Downtown Toronto               4                  Park
# 30  Downtown Toronto               4            Playground
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 14            Playground           Wings Joint     Food & Drink Shop
# 30               Airport                  Park              Bus Stop
#
#          5th Most Common Venue       6th Most Common Venue  \
# 14  Construction & Landscaping              Cosmetics Shop
# 30           Food & Drink Shop  Construction & Landscaping
#
#    7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 14           Curling Ice         Deli / Bodega      Department Store
# 30        Cosmetics Shop           Curling Ice         Deli / Bodega
#
#    10th Most Common Venue
# 14     Dim Sum Restaurant
# 30       Department Store

# %% [markdown]
# #### Result:
# It is hard to distinguish the clusters since they are skewed. However, we can clearly see that cluster 1 has coffee many shops and cluster 4 mainly consists of restaurants and shops.
